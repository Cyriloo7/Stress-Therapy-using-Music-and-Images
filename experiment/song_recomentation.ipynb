# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.4.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\cyril\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\cyril\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.0)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cyril\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.4.0)
# Using cached scikit_learn-1.4.2-cp312-cp312-win_amd64.whl (10.6 MB)
# Using cached joblib-1.4.0-py3-none-any.whl (301 kB)
# Installing collected packages: joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\cyril\Pictures\FIRE\Code\spotify_million_playlist_dataset\spotify_dataset.csv")
df = df.drop_duplicates(subset=['track_name', 'track_id'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89741 entries, 0 to 113999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        89741 non-null  int64
#  1   track_id          89741 non-null  object
#  2   artists           89740 non-null  object
#  3   album_name        89740 non-null  object
#  4   track_name        89740 non-null  object
#  5   popularity        89741 non-null  int64
#  6   duration_ms       89741 non-null  int64
#  7   explicit          89741 non-null  bool
#  8   danceability      89741 non-null  float64
#  9   energy            89741 non-null  float64
#  10  key               89741 non-null  int64
#  11  loudness          89741 non-null  float64
#  12  mode              89741 non-null  int64
#  13  speechiness       89741 non-null  float64
#  14  acousticness      89741 non-null  float64
#  15  instrumentalness  89741 non-null  float64
#  16  liveness          89741 non-null  float64
#  17  valence           89741 non-null  float64
#  18  tempo             89741 non-null  float64
#  19  time_signature    89741 non-null  int64
#  20  track_genre       89741 non-null  object
#  21  ID                2008 non-null   object
# dtypes: bool(1), float64(9), int64(6), object(6)
# memory usage: 15.1+ MB
# C:\Users\cyril\AppData\Local\Temp\ipykernel_26316\1314529148.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\cyril\Pictures\FIRE\Code\spotify_million_playlist_dataset\spotify_dataset.csv")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\cyril\Pictures\FIRE\Code\spotify_million_playlist_dataset\spotify_dataset.csv")
df = df.drop(["ID"],axis=1)
df = df.drop_duplicates(subset=['track_name', 'track_id'])
df = df.dropna()
df = df.head(50000)
df.head(5)
# Out:
# C:\Users\cyril\AppData\Local\Temp\ipykernel_26320\3714031586.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\cyril\Pictures\FIRE\Code\spotify_million_playlist_dataset\spotify_dataset.csv")
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity



def collaborative_filtering(data, song_name):

    # Check if song_name exists in the data
    if song_name not in song_user_matrix.index:
        print(f"Song '{song_name}' not found. Recommending popular songs.")
        # Recommend popular items (e.g., top N by popularity)
        popular_tracks = data.sort_values(by='popularity', ascending=False).head(10)
        recommendations = popular_tracks[['track_name', 'popularity']]
        return recommendations

    # Compute cosine similarity matrix
    cosine_sim = cosine_similarity(song_user_matrix, song_user_matrix)

    # Get song index
    song_idx = list(song_user_matrix.index).index(song_name)

    # Get pairwise similarity scores and sort
    sim_scores = sorted(enumerate(cosine_sim[song_idx]), key=lambda x: x[1], reverse=True)[1:11]

    # Prepare empty DataFrame for recommendations
    recommendations = pd.DataFrame(columns=['track_name', 'popularity','danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'similarity_score'])

    # Iterate through similar songs and extract data
    for other_song_idx, similarity in sim_scores:
        similar_song_name = song_user_matrix.index[other_song_idx]
        # Merge with original data to get song names
        similar_song_info = data[data['track_name'] == similar_song_name][['track_name', 'popularity','danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo']].copy()
        similar_song_info['similarity_score'] = similarity
        # Select relevant columns and sort by popularity
        recommendations = pd.concat([recommendations, similar_song_info.sort_values(by='popularity', ascending=False).head(1)], ignore_index=True)
    return recommendations



def content_based_filtering(data, title):
    
    # Get the index of the song that matches the title
    idx = data[data['track_name'] == title].index[0]

    # Compute the cosine similarity matrix for this song only
    cosine_sim = cosine_similarity(tfidf_matrix[idx:idx+1], tfidf_matrix)

    # Get the pairwise similarity scores of all songs with that song
    sim_scores = list(enumerate(cosine_sim[0]))

    # Sort the songs based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar songs
    sim_scores = sim_scores[1:11]

    # Get the song indices and their corresponding similarity scores
    song_indices = [i[0] for i in sim_scores]
    similarity_scores = [i[1] for i in sim_scores]

    # Get the top 10 most similar songs
    recommendations = data[['track_name', 'popularity','danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo']].iloc[song_indices]

    # Add a new column for similarity scores
    recommendations['similarity_score'] = similarity_scores

    return recommendations


numeric_features = ['popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
# Create the pivot table
song_user_matrix = df.pivot_table(index='track_name', values=numeric_features, aggfunc=sum)



df['combined_features'] = df[['artists', 'track_name','danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'track_genre']].apply(
    lambda x: ' '.join(x.astype(str)), axis=1)

tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['combined_features'])
# Out:
# C:\Users\cyril\AppData\Local\Temp\ipykernel_26320\1411423581.py:81: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   song_user_matrix = df.pivot_table(index='track_name', values=numeric_features, aggfunc=sum)

# %% [markdown]
# ## this approach uses a rank-based method

# %%
def hybrid_filtering_rank_based(data, song_name, alpha=0.4):
    # Get recommendations from collaborative filtering
    collaborative_recs = collaborative_filtering(data.copy(), song_name)
    # Rank the recommendations
    collaborative_recs['collab_rank'] = collaborative_recs['similarity_score'].rank(ascending=False)

    # Get recommendations from content-based filtering
    content_recs = content_based_filtering(data.copy(), song_name)
    # Rank the recommendations
    content_recs['content_rank'] = content_recs['similarity_score'].rank(ascending=False)

    # Combine the dataframes
    hybrid_recs = pd.concat([collaborative_recs, content_recs],axis=0)

    # Calculate a hybrid rank using the weighted average of the collaborative and content ranks
    hybrid_recs['hybrid_rank'] = alpha * hybrid_recs['collab_rank'] + (1 - alpha) * hybrid_recs['content_rank']

    # Sort by hybrid rank
    hybrid_recs = hybrid_recs.sort_values(by='hybrid_rank')

    # Select the top 10
    hybrid_recs = hybrid_recs.head(20)

    return hybrid_recs

# Example Usage (assuming 'df' is your data)
song_name = "Comedy"

recommendations = hybrid_filtering_rank_based(df.copy(), song_name)
print(f"Top recommendations for song '{song_name}':")
recommendations
# Out:
# C:\Users\cyril\AppData\Local\Temp\ipykernel_5480\1488656959.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   recommendations = pd.concat([recommendations, similar_song_info.sort_values(by='popularity', ascending=False).head(1)], ignore_index=True)
# Top recommendations for song 'Comedy':
#                                     track_name popularity  danceability  \
# 0                                       Kabira         74         0.590
# 1                                      Spirits         63         0.556
# 2                            Chasing Pavements         74         0.616
# 3      Ojos Color Sol (feat. Silvio Rodríguez)         68         0.582
# 4                      Collide (Sped Up Remix)         68         0.362
# 5                                 Jee Le Zaraa         65         0.584
# 6                                        シルエット         73         0.436
# 7                  I Hate Everything About You         74         0.498
# 8                                    affection         69         0.394
# 9                                Can't Pretend         66         0.468
# 800                                        SUN         48         0.782
# 850                                  Pop Virus         47         0.629
# 751                                    FUSHIGI         49         0.753
# 406                                        Koi         53         0.598
# 756                                   Doraemon         41         0.640
# 663       I Wanna Be Your Ghost (feat. Ghosts)         50         0.829
# 18808                                    Logic         20         0.526
# 779                           King of Anything         61         0.676
# 12675                                      常言道         20         0.498
# 18307                                  Out Out         24         0.478
#
#        energy key  loudness mode  speechiness  acousticness  instrumentalness  \
# 0       0.555   2    -6.861    1       0.0271       0.48100          0.000000
# 1       0.657   0    -6.075    1       0.0265       0.17000          0.000000
# 2       0.470   5    -6.092    0       0.0253       0.29100          0.000000
# 3       0.443   2    -7.816    1       0.0436       0.66400          0.000000
# 4       0.432   2    -9.359    0       0.1120       0.08820          0.000000
# 5       0.698   4    -6.610    0       0.0376       0.44700          0.000000
# 6       0.934   2    -2.685    1       0.0507       0.00001          0.140000
# 7       0.830   6    -5.157    0       0.0421       0.00461          0.000000
# 8       0.565   2    -7.264    1       0.1260       0.51800          0.000002
# 9       0.473   1    -8.503    0       0.0281       0.27800          0.000610
# 800     0.684   1    -5.774    1       0.0398       0.02100          0.000000
# 850     0.441   9    -4.614    1       0.1260       0.03390          0.000000
# 751     0.574   3    -4.570    1       0.0483       0.05120          0.000004
# 406     0.819   9    -2.619    1       0.0911       0.00081          0.000000
# 756     0.547   4    -4.129    1       0.0380       0.00676          0.000049
# 663     0.751  11    -4.937    0       0.0645       0.01420          0.014000
# 18808   0.837   1    -8.339    0       0.9010       0.73800          0.000002
# 779     0.762   1    -4.172    1       0.0351       0.46100          0.000000
# 12675   0.477   4    -9.477    1       0.0322       0.22800          0.000006
# 18307   0.870   2   -15.775    1       0.9100       0.74600          0.000000
#
#        liveness  valence    tempo  similarity_score  collab_rank  \
# 0        0.1920    0.191   84.027          1.000000          1.0
# 1        0.1130    0.790   80.529          1.000000          2.0
# 2        0.1110    0.325   80.030          1.000000          3.0
# 3        0.0703    0.452   78.071          1.000000          4.0
# 4        0.2640    0.256   81.290          1.000000          5.0
# 5        0.0699    0.436   79.993          1.000000          6.0
# 6        0.3210    0.384   91.481          1.000000          7.0
# 7        0.1390    0.453   89.342          1.000000          8.0
# 8        0.0853    0.308   90.773          1.000000          9.0
# 9        0.1170    0.286   79.055          1.000000         10.0
# 800      0.1250    0.858  108.171          0.364696          NaN
# 850      0.2340    0.782   78.177          0.343801          NaN
# 751      0.1410    0.527   89.024          0.334375          NaN
# 406      0.2180    0.878  158.115          0.326602          NaN
# 756      0.0585    0.950  159.992          0.316302          NaN
# 663      0.0414    0.960  129.993          0.300669          NaN
# 18808    0.6760    0.363  102.971          0.190222          NaN
# 779      0.0574    0.810  119.003          0.172881          NaN
# 12675    0.1900    0.168   75.986          0.154938          NaN
# 18307    0.9640    0.148   88.733          0.150217          NaN
#
#        content_rank  hybrid_rank
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# 5               NaN          NaN
# 6               NaN          NaN
# 7               NaN          NaN
# 8               NaN          NaN
# 9               NaN          NaN
# 800             1.0          NaN
# 850             2.0          NaN
# 751             3.0          NaN
# 406             4.0          NaN
# 756             5.0          NaN
# 663             6.0          NaN
# 18808           7.0          NaN
# 779             8.0          NaN
# 12675           9.0          NaN
# 18307          10.0          NaN

# %% [markdown]
# ## This approach uses a voting system where a song gets a vote if it appears in either the collaborative or content-based recommendations

# %%
def hybrid_filtering_voting(data, song_name, num_recs=10):
    # Get recommendations from collaborative filtering
    collaborative_recs = collaborative_filtering(data.copy(), song_name)
    collaborative_recs['vote'] = 1

    # Get recommendations from content-based filtering
    content_recs = content_based_filtering(data.copy(), song_name)
    content_recs['vote'] = 1

    # Combine the dataframes
    hybrid_recs = pd.concat([collaborative_recs, content_recs],axis=0)

    # Group by track name and sum the votes
    hybrid_recs = hybrid_recs.groupby('track_name').sum().reset_index()

    # Sort by vote, then by similarity score
    hybrid_recs = hybrid_recs.sort_values(by=['vote', 'similarity_score'], ascending=[False, False])

    # Select the top num_recs
    hybrid_recs = hybrid_recs.head(num_recs)

    return hybrid_recs

# Example Usage (assuming 'df' is your data)
song_name = "Comedy"

recommendations = hybrid_filtering_voting(df.copy(), song_name)
print(f"Top recommendations for song '{song_name}':")
recommendations
# Out:
# C:\Users\cyril\AppData\Local\Temp\ipykernel_18440\1411423581.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   recommendations = pd.concat([recommendations, similar_song_info.sort_values(by='popularity', ascending=False).head(1)], ignore_index=True)
# Top recommendations for song 'Comedy':
#                                  track_name popularity  danceability  energy  \
# 8                                    Kabira         74         0.590   0.555
# 16                                  Spirits         63         0.556   0.657
# 1                         Chasing Pavements         74         0.616   0.470
# 12  Ojos Color Sol (feat. Silvio Rodríguez)         68         0.582   0.443
# 2                   Collide (Sped Up Remix)         68         0.362   0.432
# 7                              Jee Le Zaraa         65         0.584   0.698
# 18                                    シルエット         73         0.436   0.934
# 5               I Hate Everything About You         74         0.498   0.830
# 17                                affection         69         0.394   0.565
# 0                             Can't Pretend         66         0.468   0.473
#
#    key  loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 8    2    -6.861    1       0.0271       0.48100          0.000000    0.1920
# 16   0    -6.075    1       0.0265       0.17000          0.000000    0.1130
# 1    5    -6.092    0       0.0253       0.29100          0.000000    0.1110
# 12   2    -7.816    1       0.0436       0.66400          0.000000    0.0703
# 2    2    -9.359    0       0.1120       0.08820          0.000000    0.2640
# 7    4    -6.610    0       0.0376       0.44700          0.000000    0.0699
# 18   2    -2.685    1       0.0507       0.00001          0.140000    0.3210
# 5    6    -5.157    0       0.0421       0.00461          0.000000    0.1390
# 17   2    -7.264    1       0.1260       0.51800          0.000002    0.0853
# 0    1    -8.503    0       0.0281       0.27800          0.000610    0.1170
#
#     valence   tempo  similarity_score  vote
# 8     0.191  84.027               1.0     1
# 16    0.790  80.529               1.0     1
# 1     0.325  80.030               1.0     1
# 12    0.452  78.071               1.0     1
# 2     0.256  81.290               1.0     1
# 7     0.436  79.993               1.0     1
# 18    0.384  91.481               1.0     1
# 5     0.453  89.342               1.0     1
# 17    0.308  90.773               1.0     1
# 0     0.286  79.055               1.0     1

# %% [markdown]
# ## This approach uses a threshold-based method where a song is recommended if its similarity score from either the collaborative or content-based recommendations exceeds a certain threshold

# %%
def hybrid_filtering_threshold(data, song_name, threshold=0.7):
    # Get recommendations from collaborative filtering
    collaborative_recs = collaborative_filtering(data.copy(), song_name)
    collaborative_recs = collaborative_recs[collaborative_recs['similarity_score'] > threshold]

    # Get recommendations from content-based filtering
    content_recs = content_based_filtering(data.copy(), song_name)
    content_recs = content_recs[content_recs['similarity_score'] > threshold]

    # Combine the dataframes
    hybrid_recs = pd.concat([collaborative_recs, content_recs],axis=0)

    # Remove duplicates and keep the one with the highest similarity score
    hybrid_recs = hybrid_recs.sort_values('similarity_score', ascending=False).drop_duplicates('track_name').sort_index()

    return hybrid_recs

# Example Usage (assuming 'df' is your data)
song_name = "Comedy"

recommendations = hybrid_filtering_threshold(df.copy(), song_name)
print(f"Top recommendations for song '{song_name}':")
recommendations
# Out:
# C:\Users\cyril\AppData\Local\Temp\ipykernel_18440\1411423581.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   recommendations = pd.concat([recommendations, similar_song_info.sort_values(by='popularity', ascending=False).head(1)], ignore_index=True)
# Top recommendations for song 'Comedy':
#                                 track_name popularity  danceability  energy  \
# 0                                   Kabira         74         0.590   0.555
# 1                                  Spirits         63         0.556   0.657
# 2                        Chasing Pavements         74         0.616   0.470
# 3  Ojos Color Sol (feat. Silvio Rodríguez)         68         0.582   0.443
# 4                  Collide (Sped Up Remix)         68         0.362   0.432
# 5                             Jee Le Zaraa         65         0.584   0.698
# 6                                    シルエット         73         0.436   0.934
# 7              I Hate Everything About You         74         0.498   0.830
# 8                                affection         69         0.394   0.565
# 9                            Can't Pretend         66         0.468   0.473
#
#   key  loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   2    -6.861    1       0.0271       0.48100          0.000000    0.1920
# 1   0    -6.075    1       0.0265       0.17000          0.000000    0.1130
# 2   5    -6.092    0       0.0253       0.29100          0.000000    0.1110
# 3   2    -7.816    1       0.0436       0.66400          0.000000    0.0703
# 4   2    -9.359    0       0.1120       0.08820          0.000000    0.2640
# 5   4    -6.610    0       0.0376       0.44700          0.000000    0.0699
# 6   2    -2.685    1       0.0507       0.00001          0.140000    0.3210
# 7   6    -5.157    0       0.0421       0.00461          0.000000    0.1390
# 8   2    -7.264    1       0.1260       0.51800          0.000002    0.0853
# 9   1    -8.503    0       0.0281       0.27800          0.000610    0.1170
#
#    valence   tempo  similarity_score
# 0    0.191  84.027               1.0
# 1    0.790  80.529               1.0
# 2    0.325  80.030               1.0
# 3    0.452  78.071               1.0
# 4    0.256  81.290               1.0
# 5    0.436  79.993               1.0
# 6    0.384  91.481               1.0
# 7    0.453  89.342               1.0
# 8    0.308  90.773               1.0
# 9    0.286  79.055               1.0

# %% [markdown]
# ## This approach uses a max-based method where the final similarity score for each song is the maximum of the similarity scores from the collaborative and content-based recommendations

# %%
def hybrid_filtering_max(data, song_name):
    # Get recommendations from collaborative filtering
    collaborative_recs = collaborative_filtering(data.copy(), song_name)
    #collaborative_recs = collaborative_recs[['track_name', 'similarity_score']]

    # Get recommendations from content-based filtering
    content_recs = content_based_filtering(data.copy(), song_name)
    #content_recs = content_recs[['track_name', 'similarity_score']]

    # Combine the dataframes
    hybrid_recs = pd.concat([collaborative_recs, content_recs])

    # Group by track name and take the max similarity score
    hybrid_recs = hybrid_recs.groupby('track_name').max().reset_index()

    # Sort by similarity score
    hybrid_recs = hybrid_recs.sort_values(by='similarity_score', ascending=False)

    return hybrid_recs

# Example Usage (assuming 'df' is your data)
song_name = "Comedy"

recommendations = hybrid_filtering_max(df.copy(), song_name)
print(f"Top recommendations for song '{song_name}':")
recommendations
# Out:
# C:\Users\cyril\AppData\Local\Temp\ipykernel_18440\1411423581.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   recommendations = pd.concat([recommendations, similar_song_info.sort_values(by='popularity', ascending=False).head(1)], ignore_index=True)
# Top recommendations for song 'Comedy':
#                                  track_name popularity  danceability  energy  \
# 8                                    Kabira         74         0.590   0.555
# 16                                  Spirits         63         0.556   0.657
# 1                         Chasing Pavements         74         0.616   0.470
# 12  Ojos Color Sol (feat. Silvio Rodríguez)         68         0.582   0.443
# 2                   Collide (Sped Up Remix)         68         0.362   0.432
# 7                              Jee Le Zaraa         65         0.584   0.698
# 18                                    シルエット         73         0.436   0.934
# 5               I Hate Everything About You         74         0.498   0.830
# 17                                affection         69         0.394   0.565
# 0                             Can't Pretend         66         0.468   0.473
# 15                                      SUN         48         0.782   0.684
# 14                                Pop Virus         47         0.629   0.441
# 4                                   FUSHIGI         49         0.753   0.574
# 10                                      Koi         53         0.598   0.819
# 3                                  Doraemon         41         0.640   0.547
# 6      I Wanna Be Your Ghost (feat. Ghosts)         50         0.829   0.751
# 11                                    Logic         20         0.526   0.837
# 9                          King of Anything         61         0.676   0.762
# 19                                      常言道         20         0.498   0.477
# 13                                  Out Out         24         0.478   0.870
#
#    key  loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 8    2    -6.861    1       0.0271       0.48100          0.000000    0.1920
# 16   0    -6.075    1       0.0265       0.17000          0.000000    0.1130
# 1    5    -6.092    0       0.0253       0.29100          0.000000    0.1110
# 12   2    -7.816    1       0.0436       0.66400          0.000000    0.0703
# 2    2    -9.359    0       0.1120       0.08820          0.000000    0.2640
# 7    4    -6.610    0       0.0376       0.44700          0.000000    0.0699
# 18   2    -2.685    1       0.0507       0.00001          0.140000    0.3210
# 5    6    -5.157    0       0.0421       0.00461          0.000000    0.1390
# 17   2    -7.264    1       0.1260       0.51800          0.000002    0.0853
# 0    1    -8.503    0       0.0281       0.27800          0.000610    0.1170
# 15   1    -5.774    1       0.0398       0.02100          0.000000    0.1250
# 14   9    -4.614    1       0.1260       0.03390          0.000000    0.2340
# 4    3    -4.570    1       0.0483       0.05120          0.000004    0.1410
# 10   9    -2.619    1       0.0911       0.00081          0.000000    0.2180
# 3    4    -4.129    1       0.0380       0.00676          0.000049    0.0585
# 6   11    -4.937    0       0.0645       0.01420          0.014000    0.0414
# 11   1    -8.339    0       0.9010       0.73800          0.000002    0.6760
# 9    1    -4.172    1       0.0351       0.46100          0.000000    0.0574
# 19   4    -9.477    1       0.0322       0.22800          0.000006    0.1900
# 13   2   -15.775    1       0.9100       0.74600          0.000000    0.9640
#
#     valence    tempo  similarity_score
# 8     0.191   84.027          1.000000
# 16    0.790   80.529          1.000000
# 1     0.325   80.030          1.000000
# 12    0.452   78.071          1.000000
# 2     0.256   81.290          1.000000
# 7     0.436   79.993          1.000000
# 18    0.384   91.481          1.000000
# 5     0.453   89.342          1.000000
# 17    0.308   90.773          1.000000
# 0     0.286   79.055          1.000000
# 15    0.858  108.171          0.364696
# 14    0.782   78.177          0.343801
# 4     0.527   89.024          0.334375
# 10    0.878  158.115          0.326602
# 3     0.950  159.992          0.316302
# 6     0.960  129.993          0.300669
# 11    0.363  102.971          0.190222
# 9     0.810  119.003          0.172881
# 19    0.168   75.986          0.154938
# 13    0.148   88.733          0.150217

# %% [markdown]
# ## This approach uses a min-based method where the final similarity score for each song is the minimum of the similarity scores from the collaborative and content-based recommendations

# %%
def hybrid_filtering_min(data, song_name):
    # Get recommendations from collaborative filtering
    collaborative_recs = collaborative_filtering(data.copy(), song_name)
    #collaborative_recs = collaborative_recs[['track_name', 'similarity_score']]

    # Get recommendations from content-based filtering
    content_recs = content_based_filtering(data.copy(), song_name)
    #content_recs = content_recs[['track_name', 'similarity_score']]

    # Combine the dataframes
    hybrid_recs = pd.concat([collaborative_recs, content_recs])

    # Group by track name and take the min similarity score
    hybrid_recs = hybrid_recs.groupby('track_name').min().reset_index()

    # Sort by similarity score
    hybrid_recs = hybrid_recs.sort_values(by='similarity_score', ascending=False)

    return hybrid_recs[1:11]

# Example Usage (assuming 'df' is your data)
song_name = "Comedy"

recommendations = hybrid_filtering_min(df.copy(), song_name)
print(f"Top recommendations for song '{song_name}':")
recommendations
# Out:
# C:\Users\cyril\AppData\Local\Temp\ipykernel_18440\1411423581.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   recommendations = pd.concat([recommendations, similar_song_info.sort_values(by='popularity', ascending=False).head(1)], ignore_index=True)
# Top recommendations for song 'Comedy':
#                                  track_name popularity  danceability  energy  \
# 8                                    Kabira         74         0.590   0.555
# 16                                  Spirits         63         0.556   0.657
# 1                         Chasing Pavements         74         0.616   0.470
# 12  Ojos Color Sol (feat. Silvio Rodríguez)         68         0.582   0.443
# 2                   Collide (Sped Up Remix)         68         0.362   0.432
# 7                              Jee Le Zaraa         65         0.584   0.698
# 18                                    シルエット         73         0.436   0.934
# 5               I Hate Everything About You         74         0.498   0.830
# 17                                affection         69         0.394   0.565
# 0                             Can't Pretend         66         0.468   0.473
# 15                                      SUN         48         0.782   0.684
# 14                                Pop Virus         47         0.629   0.441
# 4                                   FUSHIGI         49         0.753   0.574
# 10                                      Koi         53         0.598   0.819
# 3                                  Doraemon         41         0.640   0.547
# 6      I Wanna Be Your Ghost (feat. Ghosts)         50         0.829   0.751
# 11                                    Logic         20         0.526   0.837
# 9                          King of Anything         61         0.676   0.762
# 19                                      常言道         20         0.498   0.477
# 13                                  Out Out         24         0.478   0.870
#
#    key  loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 8    2    -6.861    1       0.0271       0.48100          0.000000    0.1920
# 16   0    -6.075    1       0.0265       0.17000          0.000000    0.1130
# 1    5    -6.092    0       0.0253       0.29100          0.000000    0.1110
# 12   2    -7.816    1       0.0436       0.66400          0.000000    0.0703
# 2    2    -9.359    0       0.1120       0.08820          0.000000    0.2640
# 7    4    -6.610    0       0.0376       0.44700          0.000000    0.0699
# 18   2    -2.685    1       0.0507       0.00001          0.140000    0.3210
# 5    6    -5.157    0       0.0421       0.00461          0.000000    0.1390
# 17   2    -7.264    1       0.1260       0.51800          0.000002    0.0853
# 0    1    -8.503    0       0.0281       0.27800          0.000610    0.1170
# 15   1    -5.774    1       0.0398       0.02100          0.000000    0.1250
# 14   9    -4.614    1       0.1260       0.03390          0.000000    0.2340
# 4    3    -4.570    1       0.0483       0.05120          0.000004    0.1410
# 10   9    -2.619    1       0.0911       0.00081          0.000000    0.2180
# 3    4    -4.129    1       0.0380       0.00676          0.000049    0.0585
# 6   11    -4.937    0       0.0645       0.01420          0.014000    0.0414
# 11   1    -8.339    0       0.9010       0.73800          0.000002    0.6760
# 9    1    -4.172    1       0.0351       0.46100          0.000000    0.0574
# 19   4    -9.477    1       0.0322       0.22800          0.000006    0.1900
# 13   2   -15.775    1       0.9100       0.74600          0.000000    0.9640
#
#     valence    tempo  similarity_score
# 8     0.191   84.027          1.000000
# 16    0.790   80.529          1.000000
# 1     0.325   80.030          1.000000
# 12    0.452   78.071          1.000000
# 2     0.256   81.290          1.000000
# 7     0.436   79.993          1.000000
# 18    0.384   91.481          1.000000
# 5     0.453   89.342          1.000000
# 17    0.308   90.773          1.000000
# 0     0.286   79.055          1.000000
# 15    0.858  108.171          0.364696
# 14    0.782   78.177          0.343801
# 4     0.527   89.024          0.334375
# 10    0.878  158.115          0.326602
# 3     0.950  159.992          0.316302
# 6     0.960  129.993          0.300669
# 11    0.363  102.971          0.190222
# 9     0.810  119.003          0.172881
# 19    0.168   75.986          0.154938
# 13    0.148   88.733          0.150217

# %% [markdown]
# ## KNN Algorithm

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\cyril\Pictures\FIRE\Code\Complete_data_cleaned_data.csv")
df = df.drop(["ID",'Spotify URL','Followers','Spotify ID','API URL','Image URL','Album Name','Album ID','Track ID',"Type"],axis=1)
df = df.drop(["Track Href",'Analysis URL','URI','Track Duration'],axis=1)
df = df.drop(["Offset Seconds",'Window Seconds','Analysis Sample Rate','Analysis Channels','End of Fade In','Start of Fade Out'],axis=1)
df = df.drop(["Analyzer Version",'Platform','Detailed Status','Analysis Time','Timestamp','Input Process','Number of Samples'],axis=1)
df = df.dropna()
df.info()
df.to_csv(r"C:\Users\cyril\Pictures\FIRE\Code\new_file.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126737 entries, 0 to 127858
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Name                       126737 non-null  object
#  1   Genres                     126737 non-null  object
#  2   Popularity                 126737 non-null  int64
#  3   Track Name                 126737 non-null  object
#  4   Loudness                   126737 non-null  float64
#  5   Tempo                      126737 non-null  float64
#  6   Tempo Confidence           126737 non-null  float64
#  7   Time Signature             126737 non-null  float64
#  8   Time Signature Confidence  126737 non-null  float64
#  9   Key                        126737 non-null  float64
#  10  Key Confidence             126737 non-null  float64
#  11  Mode                       126737 non-null  float64
#  12  Mode Confidence            126737 non-null  float64
#  13  Danceability               126737 non-null  float64
#  14  Energy                     126737 non-null  float64
#  15  Speechiness                126737 non-null  float64
#  16  Acousticness               126737 non-null  float64
#  17  Instrumentalness           126737 non-null  float64
#  18  Liveness                   126737 non-null  float64
#  19  Valence                    126737 non-null  float64
#  20  Duration ms                126737 non-null  float64
# dtypes: float64(17), int64(1), object(3)
# memory usage: 21.3+ MB

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\cyril\Pictures\FIRE\Code\new_file.csv")
df1 = df.copy()
df1 = df1.drop(['Unnamed: 0'],axis=1)
df = df.drop_duplicates(subset=["Name",'Track Name']) 
df = df.drop(["Name",'Track Name','Unnamed: 0'],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 106151 entries, 0 to 126736
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Genres                     106151 non-null  object
#  1   Popularity                 106151 non-null  int64
#  2   Loudness                   106151 non-null  float64
#  3   Tempo                      106151 non-null  float64
#  4   Tempo Confidence           106151 non-null  float64
#  5   Time Signature             106151 non-null  float64
#  6   Time Signature Confidence  106151 non-null  float64
#  7   Key                        106151 non-null  float64
#  8   Key Confidence             106151 non-null  float64
#  9   Mode                       106151 non-null  float64
#  10  Mode Confidence            106151 non-null  float64
#  11  Danceability               106151 non-null  float64
#  12  Energy                     106151 non-null  float64
#  13  Speechiness                106151 non-null  float64
#  14  Acousticness               106151 non-null  float64
#  15  Instrumentalness           106151 non-null  float64
#  16  Liveness                   106151 non-null  float64
#  17  Valence                    106151 non-null  float64
#  18  Duration ms                106151 non-null  float64
# dtypes: float64(17), int64(1), object(1)
# memory usage: 16.2+ MB

# %%
# Input features (example values, replace with actual input)
input_features = {
    'Popularity' : 73,
    'Duration ms': 230666,
    'Danceability': 0.676,
    'Energy': 0.461,
    'Key': 1,
    'Key Confidence': 0.85,
    'Loudness': -6.746,
    'Mode': 0,
    'Mode Confidence': 0.7,
    'Speechiness': 0.143,
    'Acousticness': 0.0322,
    'Instrumentalness': 0.000001,
    'Liveness': 0.358,
    'Valence': 0.715,
    'Tempo': 87.917,
    'Tempo Confidence': 0.9,
    'Time Signature': 4,
    'Time Signature Confidence': 0.85,
    'Genres': 'pop' # Example genre label (encoded)
}

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

def preprocess_data(data):

    data['Genres'] = label_encoder.fit_transform(data['Genres'])
    return data

def kNN_song_recommender(processed_data, input_features, num_recs=100):
    
    # Initialize k-NN model
    model = NearestNeighbors(n_neighbors=num_recs, metric='cosine')
    model.fit(processed_data)

    # Find indices of similar songs
    input_features_df = pd.DataFrame(input_features, index=[0])
    _, indices = model.kneighbors(input_features_df.values)

    # Get top similar songs
    top_songs_index = indices[0]
    top_songs = df1.iloc[top_songs_index]

    return top_songs


# Preprocess the data
processed_data = preprocess_data(df)
input_features['Genres'] = label_encoder.fit_transform([input_features['Genres']])
# Get recommendations based on input features
recommended_songs = kNN_song_recommender(processed_data, input_features)

print("Top 10 recommended songs:")
recommended_songs
# Out:
# Top 10 recommended songs:
# c:\Users\cyril\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#        Unnamed: 0                      Name  \
# 5306         5306             Calvin Harris
# 26195       26195             Fleetwood Mac
# 57699       57709    Florence + The Machine
# 53800       53810            French Montana
# 25673       25673           Black Eyed Peas
# ...           ...                       ...
# 90231       91353                 Glee Cast
# 75864       76986         Avenged Sevenfold
# 8559         8559               Nicki Minaj
# 25426       25426  Bob Marley & The Wailers
# 73386       74508               Johnny Cash
#
#                                                   Genres  Popularity  \
# 5306   dance pop, edm, electro house, house, pop, pop...          86
# 26195  album rock, classic rock, rock, soft rock, yac...          81
# 57699  baroque pop, electropop, modern rock, neo mell...          76
# 53800      hip hop, pop rap, rap, southern hip hop, trap          76
# 25673                            dance pop, pop, pop rap          80
# ...                                                  ...         ...
# 90231                           glee club, post-teen pop          69
# 75864                                  alternative metal          76
# 8559                   hip pop, pop, queens hip hop, rap          87
# 25426                               reggae, roots reggae          83
# 73386             arkansas country, outlaw country, rock          74
#
#                                       Track Name  Loudness    Tempo  \
# 5306      Faking It (feat. Kehlani & Lil Yachty)    -4.196  119.974
# 26195  Not That Funny - Live 1980, Cleveland, OH   -16.397  136.070
# 57699                            Never Let Me Go    -3.240  145.093
# 53800                                       Skit    -6.261  169.721
# 25673                           What's Goin Down    -3.996   90.054
# ...                                          ...       ...      ...
# 90231                           Silly Love Songs    -8.823  124.949
# 75864                                Set Me Free    -7.293  139.983
# 8559                              Feeling Myself    -5.459  101.640
# 25426                             Talkin’: Rasta   -18.788   48.341
# 73386                            Goodnight Irene    -9.261  125.845
#
#        Tempo Confidence  Time Signature  Time Signature Confidence  ...  Mode  \
# 5306              0.523             4.0                      1.000  ...   0.0
# 26195             0.625             4.0                      0.952  ...   1.0
# 57699             0.297             4.0                      1.000  ...   1.0
# 53800             0.216             3.0                      1.000  ...   0.0
# 25673             0.652             4.0                      0.996  ...   1.0
# ...                 ...             ...                        ...  ...   ...
# 90231             0.456             4.0                      1.000  ...   1.0
# 75864             0.439             4.0                      0.940  ...   1.0
# 8559              0.000             3.0                      0.987  ...   1.0
# 25426             0.177             4.0                      0.920  ...   1.0
# 73386             0.104             3.0                      1.000  ...   1.0
#
#        Mode Confidence  Danceability  Energy  Speechiness  Acousticness  \
# 5306             0.407         0.781   0.598       0.0766      0.312000
# 26195            0.744         0.461   0.563       0.0659      0.075800
# 57699            0.476         0.459   0.727       0.0359      0.297000
# 53800            0.422         0.482   0.826       0.3520      0.793000
# 25673            0.652         0.797   0.853       0.1460      0.007290
# ...                ...           ...     ...          ...           ...
# 90231            0.672         0.508   0.752       0.0521      0.435000
# 75864            0.391         0.448   0.661       0.0311      0.000415
# 8559             0.324         0.564   0.703       0.2690      0.437000
# 25426            0.435         0.799   0.308       0.9640      0.459000
# 73386            0.462         0.735   0.380       0.0401      0.716000
#
#        Instrumentalness  Liveness  Valence  Duration ms
# 5306           0.000000    0.0745    0.669     228093.0
# 26195          0.374000    0.6940    0.468     539760.0
# 57699          0.000010    0.3800    0.263     271377.0
# 53800          0.000000    0.3460    0.653      28653.0
# 25673          0.030400    0.0584    0.805     161280.0
# ...                 ...       ...      ...          ...
# 90231          0.000000    0.9390    0.381     153493.0
# 75864          0.000064    0.0499    0.213     381201.0
# 8559           0.009270    0.3580    0.477     237840.0
# 25426          0.000000    0.2250    0.512      36493.0
# 73386          0.000955    0.1890    0.422     159865.0
#
# [100 rows x 22 columns]
